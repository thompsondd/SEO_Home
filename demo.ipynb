# %%
import pandas as pd
import numpy as np

# %%
path = "Database.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#                               Tên căn hộ  \
# 0      Căn hộ chung cư Samland Riverview
# 1                Căn hộ chung cư 12 View
# 2   Căn hộ chung cư The Useful Apartment
# 3     Căn hộ chung cư Carillon Apartment
# 4        Căn hộ chung cư Chung Cư Mỹ Đức
# ..                                   ...
# 94                   TẢN ĐÀ COURT QUẬN 5
# 95                 The Everrich Infinity
# 96                        Chung cư LaKai
# 97                      STELLA RESIDENCE
# 98                  Charmington Dragonic
#
#                                           Link images Quận (Huyện)  \
# 0   http://melydecor.vn/Uploads/images/noi-that-ca...   Bình Thạnh
# 1   https://duanhungthinhpropertyx.com/wp-content/...           12
# 2   http://data.batdongsan.com.vn/Enterprises/1205...     Tân Bình
# 3   https://batdongsanexpress.vn/upload/2021/01/ba...     Tân Bình
# 4   https://photo.rever.vn/v2/get/BPzhn78Y2_511geO...   Bình Thạnh
# ...

# %%
ip = ""
